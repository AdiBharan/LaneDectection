# %%
import cv2
import matplotlib.pyplot as plt
from IPython.display import clear_output, Image, display
# %matplotlib inline

# %%
image =cv2.cvtColor(cv2.imread("D:/Python/DL/test_image.jpg"), cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)
plt.show()

# %%
import numpy as np

lane_image = np.copy(image)
lane_image.shape
# Out:
# (704, 1279, 3)

# %%
# Grayscale conversion of image
gray = cv2.cvtColor(lane_image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray,cmap='gray')
plt.show()

# %%
# Gausion blur to reduce noise
blur = cv2.GaussianBlur(gray, (5,5), 0)

plt.imshow(blur)
plt.show()

# %%
# Canny method
canny = cv2.Canny(blur, 50,150)

plt.imshow(canny)
plt.show()

# %%
# All previous steps in one

def Canny(image):
    gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    blur = cv2.GaussianBlur(gray, (5,5), 0)
    canny = cv2.Canny(blur, 50, 150)
    
    return canny

# %%
image = cv2.imread("D:/Python/DL/test_image.jpg")
lane_image = np.copy(image)
canny = Canny(lane_image)

plt.imshow(canny)
plt.show()

# %%
# A function to find region of interest 
# Apply bitwise, operation to select region of interest

def region_of_interest(image):
    height = 700
    polygons = np.array([[(250,height), (1000,height), (600,250)]])
    mask = np.zeros_like(image)
    cv2.fillPoly(mask, polygons, 255)
    masked_region = cv2.bitwise_and(image, mask)
    
    return masked_region

# %%
# Function which draws lines as detected lanes in the black image

def display_lines(image, lines):
    line_image = np.zeros_like(image)
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line.reshape(4)
            cv2.line(line_image, (x1,y1), (x2,y2), (255,0,0), 10)
    return line_image

# %%
# Reading the image, calling all the functions one by one

image = cv2.imread("D:/Python/DL/test_image.jpg")

lane_image = np.copy(image)
canny_image = Canny(lane_image)
cropped_image = region_of_interest(canny_image)

lines = cv2.HoughLinesP(cropped_image, 2, np.pi/180, 100, np.array([]), 40, 5)
line_image = display_lines(lane_image, lines)

plt.imshow(line_image)
plt.show()

# %%
# Final step
# Combine the above image containing just lines in black image with original image

combo_image = cv2.addWeighted(lane_image, 1, line_image, 1, 1)

plt.imshow(combo_image)
plt.show()

# %%
# Some optimization, refine the detection of lanes

def make_coordinates(image, line_parameters):
    slope, intercept = line_parameters
    y1 = image.shape[0]
    y2 = int(y1*(3/5))
    x1 = int((y1-intercept)/slope)
    x2 = int((y2-intercept)/slope)
    return np.array([x1,y1,x2,y2])

# %%
def average_slope_intercept(image, lines):
    left_fit = []
    right_fit = []
    
    for line in lines:
        x1, y1, x2, y2 = line.reshape(4)
        parameters = np.polyfit((x1,x2), (y1,y2), 1)
        
        slope = parameters[0]
        intercept = parameters[1]
        
        if slope < 0:
            left_fit.append((slope, intercept))
        elif slope >= 0:
            right_fit.append((slope, intercept))
            
    left_fit_average = np.average(left_fit, axis=0)
    right_fit_average = np.average(right_fit, axis=0)
        
    left_line = make_coordinates(image, left_fit_average)
    right_line = make_coordinates(image, right_fit_average)
        
    return np.array([left_line, right_line])

# %%
# Again

image = cv2.imread("D:/Python/DL/test_image.jpg")

lane_image = np.copy(image)
canny_image = Canny(lane_image)
cropped_image = region_of_interest(canny_image)

lines = cv2.HoughLinesP(cropped_image, 2, np.pi/180, 100, np.array([]), 40, 5)
averaged_lines = average_slope_intercept(lane_image, lines)
line_image = display_lines(lane_image, averaged_lines)

combo_image = cv2.addWeighted(lane_image, 1, line_image, 1, 1)

plt.imshow(combo_image)
plt.show()

# %%
cap = cv2.VideoCapture("D:/Python/DL/test_video.mp4")

# %%
while (cap.isOpened()):
   _, frame = cap.read()
   canny_image = Canny(frame)
   cropped_image = region_of_interest(canny_image)
   lines = cv2.HoughLinesP(cropped_image, 2, np.pi/180, 100, np.array([]), 40, 5)
   averaged_lines = average_slope_intercept(frame, lines)
   line_image = display_lines(frame, averaged_lines)
   combo_image = cv2.addWeighted(frame, 1, line_image, 1, 1)
    
   cv2.imshow("result", combo_image)
   if cv2.waitKey(1) == ord("q"):
       break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16148/2664968321.py in <module>
#       4    cropped_image = region_of_interest(canny_image)
#       5    lines = cv2.HoughLinesP(cropped_image, 2, np.pi/180, 100, np.array([]), 40, 5)
# ----> 6    averaged_lines = average_slope_intercept(frame, lines)
#       7    line_image = display_lines(frame, averaged_lines)
#       8    combo_image = cv2.addWeighted(frame, 1, line_image, 1, 1)
#
# ~\AppData\Local\Temp/ipykernel_16148/222701105.py in average_slope_intercept(image, lines)
#      18     right_fit_average = np.average(right_fit, axis=0)
#      19
# ---> 20     left_line = make_coordinates(image, left_fit_average)
#      21     right_line = make_coordinates(image, right_fit_average)
#      22
#
# ~\AppData\Local\Temp/ipykernel_16148/837648946.py in make_coordinates(image, line_parameters)
#       2
#       3 def make_coordinates(image, line_parameters):
# ----> 4     slope, intercept = line_parameters
#       5     y1 = image.shape[0]
#       6     y2 = int(y1*(3/5))
#
# TypeError: cannot unpack non-iterable numpy.float64 object
